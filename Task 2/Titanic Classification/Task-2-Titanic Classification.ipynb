# %%
# This code is submitted by ABHINAV BANERJEE

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pdf=pd.read_csv("Task-2-titanic.csv")

# %%
dataset=pdf

# %%
dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#checking na vales
dataset.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#replacing na with their mean values
dataset['Age'].fillna((dataset['Age'].mean().astype(int)),inplace=True)

# %%
dataset['Cabin'].isnull().sum()/len(dataset)
# Out:
# 0.7710437710437711

# %%
dataset.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
dataset.drop(['Cabin'],axis=1,inplace=True)
dataset.dropna(inplace=True)

# %%
dataset.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
plt.hist(dataset['Survived'],color='blue')
plt.xlabel('X-axis-->',fontweight ='bold')
plt.ylabel('Y-axis-->',fontweight ='bold')
# Out:
# Text(0, 0.5, 'Y-axis-->')

# %%
plt.bar(dataset['Survived'],dataset['Age'],color='green')
plt.xlabel('Survived-->',color='black',fontweight ='bold')
plt.ylabel('Age-->',color='black',fontweight ='bold')
# Out:
# Text(0, 0.5, 'Age-->')

# %%
dataset[(dataset['Survived']==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
dataset[(dataset['Survived']==1) &(dataset['Sex']=='male')]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 17            18         1       2     Williams, Mr. Charles Eugene  male
# 21            22         1       2            Beesley, Mr. Lawrence  male
# 23            24         1       1     Sloper, Mr. William Thompson  male
# 36            37         1       3                 Mamee, Mr. Hanna  male
# 55            56         1       1                Woolner, Mr. Hugh  male
# ..           ...       ...     ...                              ...   ...
# 838          839         1       3                  Chip, Mr. Chang  male
# 839          840         1       1             Marechal, Mr. Pierre  male
# 857          858         1       1           Daly, Mr. Peter Denis   male
# 869          870         1       3  Johnson, Master. Harold Theodor  male
# 889          890         1       1            Behr, Mr. Karl Howell  male
#
#       Age  SibSp  Parch  Ticket     Fare Embarked
# ...

# %%
dataset[(dataset['Survived']==1) &(dataset['Sex']=='male') & (dataset['Age']>22)]
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 17            18         1       2  Williams, Mr. Charles Eugene  male  29.0
# 21            22         1       2         Beesley, Mr. Lawrence  male  34.0
# 23            24         1       1  Sloper, Mr. William Thompson  male  28.0
# 36            37         1       3              Mamee, Mr. Hanna  male  29.0
# 55            56         1       1             Woolner, Mr. Hugh  male  29.0
# ..           ...       ...     ...                           ...   ...   ...
# 828          829         1       3  McCormack, Mr. Thomas Joseph  male  29.0
# 838          839         1       3               Chip, Mr. Chang  male  32.0
# 839          840         1       1          Marechal, Mr. Pierre  male  29.0
# 857          858         1       1        Daly, Mr. Peter Denis   male  51.0
# 889          890         1       1         Behr, Mr. Karl Howell  male  26.0
#
#      SibSp  Parch  Ticket     Fare Embarked
# ...

# %%
dataset[(dataset['Survived']==1) &(dataset['Sex']=='male') & (dataset['Age']>22)  & (dataset ['Pclass']==3)]
# Out:
#      PassengerId  Survived  Pclass  \
# 36            37         1       3
# 65            66         1       3
# 74            75         1       3
# 81            82         1       3
# 107          108         1       3
# 127          128         1       3
# 146          147         1       3
# 207          208         1       3
# 267          268         1       3
# 271          272         1       3
# 286          287         1       3
# 301          302         1       3
# 338          339         1       3
# 400          401         1       3
# 414          415         1       3
# 429          430         1       3
# 444          445         1       3
# 455          456         1       3
# 509          510         1       3
# 510          511         1       3
# 569          570         1       3
# 579          580         1       3
# 643          644         1       3
# 692          693         1       3
# 709          710         1       3
# ...

# %%
sns.barplot(x=dataset['Embarked'],y=dataset['Survived'])
# Out:
# <Axes: xlabel='Embarked', ylabel='Survived'>

# %%
#died people
dataset[(dataset['Survived']==0)]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
dataset[(dataset['Survived']==0) & (dataset['Age']>45)]
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 6              7         0       1         McCarthy, Mr. Timothy J    male
# 33            34         0       2           Wheadon, Mr. Edward H    male
# 54            55         0       1  Ostby, Mr. Engelhart Cornelius    male
# 92            93         0       1     Chaffee, Mr. Herbert Fuller    male
# 94            95         0       3               Coxon, Mr. Daniel    male
# ..           ...       ...     ...                             ...     ...
# 771          772         0       3         Jensen, Mr. Niels Peder    male
# 772          773         0       2               Mack, Mrs. (Mary)  female
# 789          790         0       1        Guggenheim, Mr. Benjamin    male
# 851          852         0       3             Svensson, Mr. Johan    male
# 873          874         0       3     Vander Cruyssen, Mr. Victor    male
#
#       Age  SibSp  Parch       Ticket     Fare Embarked
# ...

# %%
dataset[(dataset['Survived']==0) & (dataset['Age']>45) & (dataset['Sex']=='male')]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 33            34         0       2           Wheadon, Mr. Edward H  male
# 54            55         0       1  Ostby, Mr. Engelhart Cornelius  male
# 92            93         0       1     Chaffee, Mr. Herbert Fuller  male
# 94            95         0       3               Coxon, Mr. Daniel  male
# ..           ...       ...     ...                             ...   ...
# 745          746         0       1    Crosby, Capt. Edward Gifford  male
# 771          772         0       3         Jensen, Mr. Niels Peder  male
# 789          790         0       1        Guggenheim, Mr. Benjamin  male
# 851          852         0       3             Svensson, Mr. Johan  male
# 873          874         0       3     Vander Cruyssen, Mr. Victor  male
#
#       Age  SibSp  Parch       Ticket     Fare Embarked
# ...

# %%
# This code is submitted by ABHINAV BANERJEE
